# %% [markdown]
# # Generalized Roy Model
#
# This lecture introduces the Generalized Roy Model as a framework for understanding selection on observables and unobservables.

# %% [markdown]
# ## Learning Objectives
#
# - Understand the basic Roy model of self-selection
# - Extend to the Generalized Roy framework
# - Connect to identification strategies covered in later weeks

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## The Basic Roy Model
#
# Content TBD

# %% [markdown]
# ## References
#
# ```{bibliography}
# :filter: docname in docnames
# ```
